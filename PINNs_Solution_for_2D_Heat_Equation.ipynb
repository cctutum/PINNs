# %%
import torch
import torch.nn as nn
import torch.optim as optim
import seaborn as sns
import matplotlib.pyplot as plt

# %%
class PINN(nn.Module):
    def __init__(self):
        super(PINN,self).__init__()
        self.net = nn.Sequential(
            nn.Linear(3,64),
            nn.Tanh(),
            nn.Linear(64,64),
            nn.Tanh(),
            nn.Linear(64,1)
        )
    def forward(self,x):
        return self.net(x)

# %%
def intial_condition(x, y):
    return torch.sin(torch.pi * x) * torch.sin(torch.pi * y)

def boundary_condition(x, y, t, custom_value):
    return torch.full_like(x, custom_value)

# %%
def generate_training_data(num_points):
    x = torch.rand(num_points, 1, requires_grad = True)
    y = torch.rand(num_points, 1, requires_grad = True)
    t = torch.rand(num_points, 1, requires_grad = True)
    return x, y, t

# %%
def generate_boundary_points(num_points):
    x_boundary = torch.tensor([0.0,1.0]).repeat(num_points//2)
    y_boundary = torch.rand(num_points)
    if torch.rand(1) > 0.5:
        x_boundary, y_boundary = y_boundary,x_boundary
    return x_boundary.view(-1,1), y_boundary.view(-1,1)


def generate_boundary_training_data(num_points):
    x_boundary, y_boundary = generate_boundary_points(num_points)
    t = torch.rand(num_points, 1, requires_grad= True)
    return x_boundary, y_boundary, t

# %%
def pde(x, y, t, model):
    input_data = torch.cat([x, y, t],dim=1)
    u = model(input_data)
    u_x, u_y = torch.autograd.grad(u, [x, y], grad_outputs=torch.ones_like(u), create_graph=True, retain_graph=True) 
    u_xx = torch.autograd.grad(u_x, x, grad_outputs=torch.ones_like(u_x), create_graph=True, retain_graph=True)[0]
    u_yy = torch.autograd.grad(u_y, y, grad_outputs=torch.ones_like(u_y), create_graph=True, retain_graph=True)[0]
    u_t = torch.autograd.grad(u, t, grad_outputs=torch.ones_like(u), create_graph=True, retain_graph=True)[0]
    heat_eq_residual = 1 * u_xx + 1 * u_yy - u_t
    return heat_eq_residual

# %%
def train_PINN(model, num_iterations, num_points):
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    
    for  iteration in range(num_iterations):
        optimizer.zero_grad()
        
        x, y, t = generate_training_data(num_points)
        
        x_b, y_b, t_b = generate_boundary_training_data(num_points)
        
        t_intial = torch.zeros_like(t)
        u_intial = intial_condition(x, y)
        
        custom_value = 0
        u_boundary_x = boundary_condition(x_b, y_b, t_b, custom_value)
        u_boundary_y = boundary_condition(y_b, x_b, t_b, custom_value)
        
        residual = pde(x,y,t,model)
        
        loss =  nn.MSELoss()(u_intial, model(torch.cat([x, y, t_intial], dim=1))) + \
                nn.MSELoss()(u_boundary_x, model(torch.cat([x_b, y_b, t_b], dim=1))) + \
                nn.MSELoss()(u_boundary_y, model(torch.cat([y_b, x_b, t_b], dim=1))) + \
                nn.MSELoss()(residual, torch.zeros_like(residual))
                
        loss.backward()
        optimizer.step()
        
        if iteration % 100 ==0:
            print("itration", iteration, "loss", loss )

# %%
model = PINN()
num_iterations = 10000
num_points = 1000
train_PINN(model, num_iterations, num_points)
# Out:
# itration 0 loss tensor(0.3706, grad_fn=<AddBackward0>)
# itration 100 loss tensor(0.1243, grad_fn=<AddBackward0>)
# itration 200 loss tensor(0.1247, grad_fn=<AddBackward0>)
# itration 300 loss tensor(0.1215, grad_fn=<AddBackward0>)
# itration 400 loss tensor(0.1037, grad_fn=<AddBackward0>)
# itration 500 loss tensor(0.0817, grad_fn=<AddBackward0>)
# itration 600 loss tensor(0.0734, grad_fn=<AddBackward0>)
# itration 700 loss tensor(0.0627, grad_fn=<AddBackward0>)
# itration 800 loss tensor(0.0589, grad_fn=<AddBackward0>)
# itration 900 loss tensor(0.0506, grad_fn=<AddBackward0>)
# itration 1000 loss tensor(0.0445, grad_fn=<AddBackward0>)
# itration 1100 loss tensor(0.0432, grad_fn=<AddBackward0>)
# itration 1200 loss tensor(0.0369, grad_fn=<AddBackward0>)
# itration 1300 loss tensor(0.0343, grad_fn=<AddBackward0>)
# itration 1400 loss tensor(0.0309, grad_fn=<AddBackward0>)
# itration 1500 loss tensor(0.0287, grad_fn=<AddBackward0>)
# itration 1600 loss tensor(0.0277, grad_fn=<AddBackward0>)
# itration 1700 loss tensor(0.0249, grad_fn=<AddBackward0>)
# itration 1800 loss tensor(0.0213, grad_fn=<AddBackward0>)
# itration 1900 loss tensor(0.0186, grad_fn=<AddBackward0>)
# itration 2000 loss tensor(0.0166, grad_fn=<AddBackward0>)
# itration 2100 loss tensor(0.0164, grad_fn=<AddBackward0>)
# itration 2200 loss tensor(0.0146, grad_fn=<AddBackward0>)
# itration 2300 loss tensor(0.0149, grad_fn=<AddBackward0>)
# itration 2400 loss tensor(0.0146, grad_fn=<AddBackward0>)
# itration 2500 loss tensor(0.0129, grad_fn=<AddBackward0>)
# itration 2600 loss tensor(0.0130, grad_fn=<AddBackward0>)
# itration 2700 loss tensor(0.0137, grad_fn=<AddBackward0>)
# itration 2800 loss tensor(0.0126, grad_fn=<AddBackward0>)
# itration 2900 loss tensor(0.0102, grad_fn=<AddBackward0>)
# itration 3000 loss tensor(0.0099, grad_fn=<AddBackward0>)
# itration 3100 loss tensor(0.0105, grad_fn=<AddBackward0>)
# itration 3200 loss tensor(0.0101, grad_fn=<AddBackward0>)
# itration 3300 loss tensor(0.0104, grad_fn=<AddBackward0>)
# itration 3400 loss tensor(0.0103, grad_fn=<AddBackward0>)
# itration 3500 loss tensor(0.0085, grad_fn=<AddBackward0>)
# itration 3600 loss tensor(0.0098, grad_fn=<AddBackward0>)
# itration 3700 loss tensor(0.0087, grad_fn=<AddBackward0>)
# itration 3800 loss tensor(0.0096, grad_fn=<AddBackward0>)
# itration 3900 loss tensor(0.0083, grad_fn=<AddBackward0>)
# itration 4000 loss tensor(0.0084, grad_fn=<AddBackward0>)
# itration 4100 loss tensor(0.0084, grad_fn=<AddBackward0>)
# itration 4200 loss tensor(0.0077, grad_fn=<AddBackward0>)
# itration 4300 loss tensor(0.0072, grad_fn=<AddBackward0>)
# itration 4400 loss tensor(0.0069, grad_fn=<AddBackward0>)
# itration 4500 loss tensor(0.0071, grad_fn=<AddBackward0>)
# itration 4600 loss tensor(0.0075, grad_fn=<AddBackward0>)
# itration 4700 loss tensor(0.0066, grad_fn=<AddBackward0>)
# itration 4800 loss tensor(0.0063, grad_fn=<AddBackward0>)
# itration 4900 loss tensor(0.0063, grad_fn=<AddBackward0>)
# itration 5000 loss tensor(0.0066, grad_fn=<AddBackward0>)
# itration 5100 loss tensor(0.0067, grad_fn=<AddBackward0>)
# itration 5200 loss tensor(0.0068, grad_fn=<AddBackward0>)
# itration 5300 loss tensor(0.0062, grad_fn=<AddBackward0>)
# itration 5400 loss tensor(0.0051, grad_fn=<AddBackward0>)
# itration 5500 loss tensor(0.0063, grad_fn=<AddBackward0>)
# itration 5600 loss tensor(0.0063, grad_fn=<AddBackward0>)
# itration 5700 loss tensor(0.0062, grad_fn=<AddBackward0>)
# itration 5800 loss tensor(0.0058, grad_fn=<AddBackward0>)
# itration 5900 loss tensor(0.0051, grad_fn=<AddBackward0>)
# itration 6000 loss tensor(0.0052, grad_fn=<AddBackward0>)
# itration 6100 loss tensor(0.0046, grad_fn=<AddBackward0>)
# itration 6200 loss tensor(0.0052, grad_fn=<AddBackward0>)
# itration 6300 loss tensor(0.0050, grad_fn=<AddBackward0>)
# itration 6400 loss tensor(0.0048, grad_fn=<AddBackward0>)
# itration 6500 loss tensor(0.0054, grad_fn=<AddBackward0>)
# itration 6600 loss tensor(0.0047, grad_fn=<AddBackward0>)
# itration 6700 loss tensor(0.0041, grad_fn=<AddBackward0>)
# itration 6800 loss tensor(0.0042, grad_fn=<AddBackward0>)
# itration 6900 loss tensor(0.0042, grad_fn=<AddBackward0>)
# itration 7000 loss tensor(0.0044, grad_fn=<AddBackward0>)
# itration 7100 loss tensor(0.0055, grad_fn=<AddBackward0>)
# itration 7200 loss tensor(0.0044, grad_fn=<AddBackward0>)
# itration 7300 loss tensor(0.0040, grad_fn=<AddBackward0>)
# itration 7400 loss tensor(0.0045, grad_fn=<AddBackward0>)
# itration 7500 loss tensor(0.0055, grad_fn=<AddBackward0>)
# itration 7600 loss tensor(0.0041, grad_fn=<AddBackward0>)
# itration 7700 loss tensor(0.0040, grad_fn=<AddBackward0>)
# itration 7800 loss tensor(0.0046, grad_fn=<AddBackward0>)
# itration 7900 loss tensor(0.0034, grad_fn=<AddBackward0>)
# itration 8000 loss tensor(0.0042, grad_fn=<AddBackward0>)
# itration 8100 loss tensor(0.0038, grad_fn=<AddBackward0>)
# itration 8200 loss tensor(0.0038, grad_fn=<AddBackward0>)
# itration 8300 loss tensor(0.0033, grad_fn=<AddBackward0>)
# itration 8400 loss tensor(0.0040, grad_fn=<AddBackward0>)
# itration 8500 loss tensor(0.0031, grad_fn=<AddBackward0>)
# itration 8600 loss tensor(0.0032, grad_fn=<AddBackward0>)
# itration 8700 loss tensor(0.0041, grad_fn=<AddBackward0>)
# itration 8800 loss tensor(0.0035, grad_fn=<AddBackward0>)
# itration 8900 loss tensor(0.0029, grad_fn=<AddBackward0>)
# itration 9000 loss tensor(0.0033, grad_fn=<AddBackward0>)
# itration 9100 loss tensor(0.0034, grad_fn=<AddBackward0>)
# itration 9200 loss tensor(0.0028, grad_fn=<AddBackward0>)
# itration 9300 loss tensor(0.0034, grad_fn=<AddBackward0>)
# itration 9400 loss tensor(0.0030, grad_fn=<AddBackward0>)
# itration 9500 loss tensor(0.0030, grad_fn=<AddBackward0>)
# itration 9600 loss tensor(0.0037, grad_fn=<AddBackward0>)
# itration 9700 loss tensor(0.0033, grad_fn=<AddBackward0>)
# itration 9800 loss tensor(0.0027, grad_fn=<AddBackward0>)
# itration 9900 loss tensor(0.0029, grad_fn=<AddBackward0>)

# %%
with torch.no_grad():
    x_vals = torch.linspace(0, 1, 100)
    y_vals = torch.linspace(0, 1, 100)
    X, Y = torch.meshgrid(x_vals, y_vals)
    t_val = torch.ones_like(X) * 0 # spacify the time
    
    input_data = torch.stack([X.flatten(), Y.flatten(), t_val.flatten()], dim=1)
    solution = model(input_data).reshape(X.shape, Y.shape)
    
    plt.figure(figsize=(8,6))
    sns.heatmap(solution, cmap="jet")
    plt.title("2D Heat Equation Solution")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.show()
# Out:
# /home/ctutum/anaconda3/envs/PYG/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /opt/conda/conda-bld/pytorch_1699449201336/work/aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
with torch.no_grad():
    x_vals = torch.linspace(0, 1, 100)
    y_vals = torch.linspace(0, 1, 100)
    X, Y = torch.meshgrid(x_vals, y_vals)
    t_val = torch.ones_like(X) * 1 # spacify the time
    
    input_data = torch.stack([X.flatten(), Y.flatten(), t_val.flatten()], dim=1)
    solution = model(input_data).reshape(X.shape, Y.shape)
    
    plt.figure(figsize=(8,6))
    sns.heatmap(solution, cmap="jet")
    plt.title("2D Heat Equation Solution")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.show()
